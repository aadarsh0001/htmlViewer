# %%
from IPython.display import display, HTML

html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>About Me - Aadarsh Tiwari</title>
    <style>
        :root {
            --bs-heading-color: var(--px-heading);
            --px-theme: #0788ff;
            --px-theme-rgb: 7, 136, 255;
            --px-text: #707476;
            --px-heading: #fff;
        }

        body {
            --bs-body-font-weight: 400;
            --bs-body-font-size: 1rem;
            --bs-body-line-height: 1.6;
            background-color: var(--px-bg);
            background: linear-gradient(90deg, #07233b 1.67%, #041d34 39.95%, #04192d 58.24%, #040e18 80.28%, #050c16 101.48%);
            color: var(--px-text);
            font-family: Space Grotesk, sans-serif;
            overflow-x: hidden;
            margin: 0;
        }

        .about-me-container {
            max-width: 800px;
            margin: 50px auto;
            padding: 20px;
            background-color: #fff;
            border-radius: 8px;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
        }

        h1 {
            color: var(--px-heading);
        }

        p {
            font-size: 1.2rem;
            line-height: 1.5;
            color: var(--px-text);
        }
    </style>
</head>
<body>
    <div class="about-me-container">
        <h1>About Me</h1>
        <p>I'm a software engineer, my name is Aadarsh Tiwari.</p>
    </div>
</body>
</html>
"""

css_content = """

"""

# Combine HTML and CSS into a single string
html_with_css = f"<style>{css_content}</style>{html_content}"

# Display the HTML content as output
display(HTML(html_with_css))
# Out:
# <style>
#
# </style>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>About Me - Aadarsh Tiwari</title>
#     <style>
#         :root {
#             --bs-heading-color: var(--px-heading);
#             --px-theme: #0788ff;
#             --px-theme-rgb: 7, 136, 255;
#             --px-text: #707476;
#             --px-heading: #fff;
#         }
#
#         body {
#             --bs-body-font-weight: 400;
#             --bs-body-font-size: 1rem;
#             --bs-body-line-height: 1.6;
#             background-color: var(--px-bg);
#             background: linear-gradient(90deg, #07233b 1.67%, #041d34 39.95%, #04192d 58.24%, #040e18 80.28%, #050c16 101.48%);
#             color: var(--px-text);
#             font-family: Space Grotesk, sans-serif;
#             overflow-x: hidden;
#             margin: 0;
#         }
#
#         .about-me-container {
# ...
